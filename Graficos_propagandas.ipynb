# %%
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
# set width of bar
barWidth = 0.25

# set height of bar
bars1 = [0.79, 0.81, 0.84, 0.86]
bars2 = [0.9287, 0.9233, 0.9261, 0.8871]

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

# Make the plot
plt.bar(r1, bars1, color='red', width=barWidth, edgecolor='black', hatch="//", label='Handcrafted')
plt.bar(r2, bars2, color='blue', width=barWidth, edgecolor='black', hatch='o', label='Data-driven')

 
# Add xticks on the middle of the group bars
plt.xlabel('Dataset', fontsize=16)
#plt.xticks([0.25, 1.25, 2.25, 3.25], ['1 sec', '2 sec', '5 sec', '10 sec'])
plt.xticks([r + (barWidth/2) for r in range(len(bars1))], ['1s', '2s', '5s', '10s'], fontsize=16)
plt.ylabel('F1-score', fontsize=16)
plt.ylim(0, 1.2)

# Create legend & Show graphic
plt.legend(fontsize=14)
#fig.savefig("performance_propaganda.pdf")
#fig.savefig("performance_propaganda.png")
plt.show()

# %%
#Resultados performance treino com limpa e 70% com stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,12))

# features + SVM
c_s = [0.85, 0.79, 0.79, 0.77]
tt_s = [0.88, 0.8, 0.81, 0.73]
nt_s = [0.45, 0.5, 0.55, 0.54]
tn_s = [0.70, 0.69, 0.70, 0.69]

# CNN + SVM
c_cs = [0.84, 0.81, 0.81, 0.80]
tt_cs = [0.84, 0.82, 0.81, 0.80]
nt_cs = [0.81, 0.76, 0.74, 0.74]
tn_cs = [0.82, 0.77, 0.77, 0.76]

# CNN + densa
c_cd = [0.90, 0.84, 0.81, 0.84]
tt_cd = [0.89, 0.85, 0.79, 0.84]
nt_cd = [0.79, 0.72, 0.77, 0.69]
tn_cd = [0.84, 0.80, 0.80, 0.79]

# Random + SVM
c_rs = [0.91, 0.87, 0.86, 0.84]
tt_rs = [0.89, 0.87, 0.86, 0.84]
nt_rs = [0.76, 0.75, 0.76, 0.76]
tn_rs = [0.82, 0.80, 0.79, 0.78]

x = range(4)
R = ['5s', '1s', '0.75s', '0.5s']

# plt.plot(x, c_s, '--^b', label='Completa_SVM', linewidth=3.0, markersize=12)
# plt.plot(x, tt_s, '--sb', label='TT_SVM', linewidth=3.0, markersize=12)
# plt.plot(x, nt_s, '--ob', label='NT_SVM', linewidth=3.0, markersize=12)
# plt.plot(x, tn_s, '--b*', label='TN_SVM', linewidth=3.0, markersize=12)

# plt.plot(x, c_cs, '--^r', label='Completa_CNN+SVM', linewidth=3.0, markersize=12)
# plt.plot(x, tt_cs, '--sr', label='TT_CNN+SVM', linewidth=3.0, markersize=12)
# plt.plot(x, nt_cs, '--or', label='NT_CNN+SVM', linewidth=3.0, markersize=12)
# plt.plot(x, tn_cs, '--r*', label='TN_CNN+SVM', linewidth=3.0, markersize=12)

# plt.plot(x, c_cd, '--^g', label='Completa_CNN+Densa', linewidth=3.0, markersize=12)
# plt.plot(x, tt_cd, '--sg', label='TT_CNN+Densa', linewidth=3.0, markersize=12)
# plt.plot(x, nt_cd, '--go', label='NT_CNN+Densa', linewidth=3.0, markersize=12)
# plt.plot(x, tn_cd, '--g*', label='TN_CNN+Densa', linewidth=3.0, markersize=12)
#plt.subplot(211)

f = plt.plot(x, c_s, '--^b', label='Completa Handcrafted+SVM', linewidth=1.5, markersize=12)
f2 = plt.plot(x, tt_s, '--sb', label='TT Handcrafted+SVM', linewidth=1.5, markersize=12)
f3 = plt.plot(x, nt_s, '--ob', label='NT Handcrafted+SVM', linewidth=1.5, markersize=12)
f4 = plt.plot(x, tn_s, '--b*', label='TN Handcrafted+SVM', linewidth=1.5, markersize=12)

y = plt.plot(x, c_cs, '--^', color='orange', label='Completa CNN+SVM', linewidth=1.5, markersize=12)
y2 = plt.plot(x, tt_cs, '--s', color='orange', label='TT CNN+SVM', linewidth=1.5, markersize=12)
y3 = plt.plot(x, nt_cs, '--o', color='orange', label='NT CNN+SVM', linewidth=1.5, markersize=12)
y4 = plt.plot(x, tn_cs, '--*', color='orange', label='TN CNN+SVM', linewidth=1.5, markersize=12)

g = plt.plot(x, c_cd, '--^g', label='Completa CNN+Densa', linewidth=1.5, markersize=12)
g2 = plt.plot(x, tt_cd, '--sg', label='TT CNN+Densa', linewidth=1.5, markersize=12)
g3 = plt.plot(x, nt_cd, '--go', label='NT CNN+Densa', linewidth=1.5, markersize=12)
g4 = plt.plot(x, tn_cd, '--g*', label='TN CNN+Densa', linewidth=1.5, markersize=12)

z = plt.plot(x, c_rs, '--^r', label='Completa Random+SVM', linewidth=1.5, markersize=12)
z2 = plt.plot(x, tt_rs, '--sr', label='TT Random+SVM', linewidth=1.5, markersize=12)
z3 = plt.plot(x, nt_rs, '--or', label='NT Random+SVM', linewidth=1.5, markersize=12)
z4 = plt.plot(x, tn_rs, '--r*', label='TN Random+SVM', linewidth=1.5, markersize=12)

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=4, ncol=4, mode="expand", borderaxespad=0., fontsize=12)


#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
#plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.xlabel('Except audio length', fontsize=16)
plt.xticks(x, R, fontsize=16)
plt.ylabel('F1-score', fontsize=16)

fig.savefig("Resultados_Graficos/Geral.png")
#fig.savefig("performance_limpa+70.pdf",bbox_extra_artists='legend')
plt.show()

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,8))
# set width of bar

# features + SVM
c_s = [0.85, 0.79, 0.79, 0.77]
tt_s = [0.88, 0.8, 0.81, 0.73]
nt_s = [0.45, 0.5, 0.55, 0.54]
tn_s = [0.70, 0.69, 0.70, 0.69]

# CNN + SVM
c_cs = [0.84, 0.81, 0.81, 0.80]
tt_cs = [0.84, 0.82, 0.81, 0.80]
nt_cs = [0.81, 0.76, 0.74, 0.74]
tn_cs = [0.82, 0.77, 0.77, 0.76]

# CNN + densa
c_cd = [0.90, 0.84, 0.81, 0.84]
tt_cd = [0.89, 0.85, 0.79, 0.84]
nt_cd = [0.79, 0.72, 0.77, 0.69]
tn_cd = [0.84, 0.80, 0.80, 0.79]

c_rs = [0.91, 0.87, 0.86, 0.84]
tt_rs = [0.89, 0.87, 0.86, 0.84]
nt_rs = [0.76, 0.75, 0.76, 0.76]
tn_rs = [0.82, 0.80, 0.79, 0.78]


# Set position of bar on X axis
barWidth = 0.2
r1 = np.arange(len(c_s))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]




# Make the plot
# plt.bar(r1, c_s, color='red', width=barWidth, edgecolor='black', hatch="//", label='Handcrafted')
# plt.bar(r2, c_cs, color='blue', width=barWidth, edgecolor='black', hatch='o', label='Data-driven+SVM')
# plt.bar(r3, c_cd, color='green', width=barWidth, edgecolor='black', hatch='+', label='Data-driven+Densa')
#plt.bar(r4, c_rs, color='orange', width=barWidth, edgecolor='black', hatch='-', label='Random+SVM')

# Completa
# rects1 = plt.bar(r1, c_s, width, label='Handcrafted')
# rects2 = plt.bar(r2, c_cs, width, label='Data-driven+SVM')
# rects3 = plt.bar(r3, c_cd, width, label='Data-driven+Densa')
# rects4 = plt.bar(r4, c_rs, width, label='Random+SVM')

# Trans_Trans
# rects1 = plt.bar(r1, tt_s, width, label='Handcrafted')
# rects2 = plt.bar(r2, tt_cs, width, label='Data-driven+SVM')
# rects3 = plt.bar(r3, tt_cd, width, label='Data-driven+Densa')
# rects4 = plt.bar(r4, tt_rs, width, label='Random+SVM')

# NoTrans_Trans
# rects1 = plt.bar(r1, nt_s, width, label='Handcrafted')
# rects2 = plt.bar(r2, nt_cs, width, label='Data-driven+SVM')
# rects3 = plt.bar(r3, nt_cd, width, label='Data-driven+Densa')
# rects4 = plt.bar(r4, nt_rs, width, label='Random+SVM')

# Trans_NoTrans
rects1 = plt.bar(r1, tn_s, width, label='Handcrafted')
rects2 = plt.bar(r2, tn_cs, width, label='Data-driven+SVM')
rects3 = plt.bar(r3, tn_cd, width, label='Data-driven+Densa')
rects4 = plt.bar(r4, tn_rs, width, label='Random+SVM')

plt.title("Trans_NoTrans", fontsize=16)
#plt.title("Completa", fontsize=16)


# Add xticks on the middle of the group bars
plt.xlabel('Dataset', fontsize=16)
#plt.xticks([0.25, 1.25, 2.25, 3.25], ['1 sec', '2 sec', '5 sec', '10 sec'])
plt.xticks([r + (barWidth*1.5) for r in range(len(c_s))], ['5s', '1s', '0.75s', '0.5s'], fontsize=16)
plt.ylabel('F1-score', fontsize=16)
plt.ylim(0, 1.4)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

        
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
        
        
# Create legend & Show graphic
plt.legend(fontsize=14)
#fig.savefig("performance_propaganda.pdf")
fig.savefig("Resultados_Graficos/Trans_NoTrans.png")
#fig.savefig("Resultados_Graficos/Completa.png")
plt.show()

# %%
#Resultados performance treino com limpa e 70% com stratified
# %matplotlib inline
#import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,12))

# Set position of bar on X axis
barWidth = 0.2
r1 = np.arange(len(c_s))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]

# features + SVM
h_m = [0.79, 0.81, 0.52, 0.70]
cnn_svm_m = [0.81, 0.82, 0.75, 0.77]
cnn_d_m = [0.84, 0.85, 0.75, 0.80]
r_m = [0.87, 0.87, 0.76, 0.80]

h_v = [0.0346, 0.0614, 0.0455, 0.0058]
cnn_svm_v = [0.0150, 0.0148, 0.0328, 0.0235]
cnn_d_v = [0.0327, 0.0356, 0.0396, 0.0192]
r_v = [0.0255, 0.0180, 0.0043, 0.0148]

x = range(4)
R = ['Cs', 'TT', 'NTT', 'TNT']

rects1 = plt.bar(r1, h_m, width, yerr=h_v, label='Handcrafted+SVM', align='center', alpha=0.8, ecolor='black', capsize=10, hatch="//", edgecolor='white')
rects2 = plt.bar(r2, cnn_svm_m, width, yerr=cnn_svm_v, label='CNN+SVM', align='center', alpha=0.8, ecolor='black', capsize=10, hatch='o', edgecolor='white')
rects3 = plt.bar(r3, cnn_d_m, width, yerr=cnn_d_v, label='CNN+Densa', align='center', alpha=0.8, ecolor='black', capsize=10, hatch='+', edgecolor='white')
rects4 = plt.bar(r4, r_m, width, yerr=r_v, label='Random+SVM', align='center', alpha=0.8, ecolor='black', capsize=10, hatch='\\', edgecolor='white')

# f = plt.plot(x, h_m, '--^b', label='Handcrafted+SVM', linewidth=1.5, markersize=12)
# f2 = plt.plot(x, cnn_svm_m, '--s', color='orange', label='CNN+SVM', linewidth=1.5, markersize=12)
# f3 = plt.plot(x, cnn_d_m, '--og', label='CNN+Densa', linewidth=1.5, markersize=12)
# f4 = plt.plot(x, r_m, '--r*', label='Random+SVM', linewidth=1.5, markersize=12)

# plt.errorbar(x, h_m, h_v, '--^b', label='Handcrafted+SVM', linewidth=1.5, markersize=12)
# plt.errorbar(x, cnn_svm_m, cnn_svm_v, '--s', color='orange', label='CNN+SVM', linewidth=1.5, markersize=12)
# plt.errorbar(x, cnn_d_m, cnn_d_v, '--og', label='CNN+Densa', linewidth=1.5, markersize=12)
# plt.errorbar(x, r_m, r_v, '--r*', label='Random+SVM', linewidth=1.5, markersize=12)



# plt.errorbar(x, h_m, h_v, marker='^', markersize=12)
# plt.errorbar(x, cnn_svm_m, cnn_svm_v, marker='s', markersize=12)
# plt.errorbar(x, cnn_d_m, cnn_d_v, marker='o', markersize=12)
# plt.errorbar(x, r_m, r_v, marker='*', markersize=12)


# y = plt.plot(x, c_cs, '--^', color='orange', label='Completa CNN+SVM', linewidth=1.5, markersize=12)
# y2 = plt.plot(x, tt_cs, '--s', color='orange', label='TT CNN+SVM', linewidth=1.5, markersize=12)
# y3 = plt.plot(x, nt_cs, '--o', color='orange', label='NT CNN+SVM', linewidth=1.5, markersize=12)
# y4 = plt.plot(x, tn_cs, '--*', color='orange', label='TN CNN+SVM', linewidth=1.5, markersize=12)

# g = plt.plot(x, c_cd, '--^g', label='Completa CNN+Densa', linewidth=1.5, markersize=12)
# g2 = plt.plot(x, tt_cd, '--sg', label='TT CNN+Densa', linewidth=1.5, markersize=12)
# g3 = plt.plot(x, nt_cd, '--go', label='NT CNN+Densa', linewidth=1.5, markersize=12)
# g4 = plt.plot(x, tn_cd, '--g*', label='TN CNN+Densa', linewidth=1.5, markersize=12)

# z = plt.plot(x, c_rs, '--^r', label='Completa Random+SVM', linewidth=1.5, markersize=12)
# z2 = plt.plot(x, tt_rs, '--sr', label='TT Random+SVM', linewidth=1.5, markersize=12)
# z3 = plt.plot(x, nt_rs, '--or', label='NT Random+SVM', linewidth=1.5, markersize=12)
# z4 = plt.plot(x, tn_rs, '--r*', label='TN Random+SVM', linewidth=1.5, markersize=12)

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=4, ncol=4, mode="expand", borderaxespad=0., fontsize=16)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(-18,1 ),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

        
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

#plt.legend(bbox_to_anchor=(.05, 0.5), loc='best')
#plt.xlabel(u'Níveis de reverberação [%]', fontsize=16)
plt.xlabel('Subdataset', fontsize=16)
#plt.xticks(x, R, fontsize=16)
plt.xticks([r + (barWidth*1.5) for r in range(len(c_s))], ['Completa', 'Trans-Trans', 'NoTrans-Trans', 'Trans-NoTrans'], fontsize=16)
plt.ylabel('Average F1-score', fontsize=16)
#plt.grid(True, axis='y')
#plt.ylim(0, 1.4)

plt.tight_layout()
fig.savefig("Resultados_Graficos/Media_subdataset.png")
#fig.savefig("performance_limpa+70.pdf",bbox_extra_artists='legend')
plt.show()
